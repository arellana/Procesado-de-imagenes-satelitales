# %% [markdown]
# ![logos.png](attachment:logos.png)
# # Escuela de Ciencias Informáticas - 2022 - DC - FCEN - UBA
# ## Curso: Procesamiento de Imágenes Satelitales.  Docente: Rafael Grimson

# %% [markdown]
# ---
# #  Notebook 1: Introducción al curso y a la teledetección
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
#
# # Quienes somos:
#
#
# # LETyE  - UNSAM-CONICET
# ## Laboratorio de Ecología, Teledetección y Ecoinformática

# %% [markdown]
# ### Investigadores:
# - Patricia Kandus
# - Priscilla Minotti
# - Rafael Grimson
# - Gabriela González Trilla
# - Natalia Morandeira
# - Estefanía Piegari
#
# ### Tesistas doctorales
# - Verónica Kwaterka, (Geóloga)
# - Soledad Nomdedeu, (Bióloga)
# - Joaquin Orzanco, (Geólogo)
# - Pablo Macagno, (Geógrafo)
# - Lucía Migone, (Cs Ambientales)
# - David Clauser, (Biólogo)
# - Vanesa Ali Santoro, (Cs Ambientales)
# - Mariela Rajngewerc, (Matemática) recién doctorada

# %% [markdown]
# # Qué hacemos:
#
# ### Usamos la ecología, el modelado matemátco y la teledetección como herramientaspara resolver  problemáticas ambientales.
# Estudiamos humedales con imágenes satelitales, trabajo de campo y modelos que permitan describir su dinámica y aportar a su conservación y uso sustentable. Hacemos ciencia y también transferencia a la gestión.
#
# Yo estoy involucrado en dos lineas de investigación:
# - Inventario de humedales.
# - Modelado hidrodinámico del delta del Paraná.

# %% [markdown]
# ---
# ![image.png](attachment:image.png)
# Estas clases fueron preparadas por Rafael Grimson (IIIA, CONICET-UNSAM, rgrimson@unsam.edu.ar) usando material de varios autorxs, entre ellxs: Patricia Kandus (3iA, UNSAM), Facundo Schivo (IIIA, CONICET-UNSAM), Andrés Solarte y Santiago Seppi (I.Gulich, UNC-CONEA).
# ---

# %% [markdown]
# ## Temario y listado de notebooks del curso
#
# 1. Clase 1:
#     1. Misiones Satelitales y Espectro Electromagnético
#     2. Imágenes como arrays
#     3. Lectura y visualización de imágenes satelitales
# 2. Clase 2:
#     4. Recortes, Indices, Georeferenciación y sistemas de coordenadas
#     5. Datos vectoriales
#     6. Vectores y rasters
# 3. Clase 3:
#     7. La misión Sentinel-2 y su lectura en Python
#     8. Un sitio de estudio
#     9. Análsis exploratorio de datos
#     10. Aprendizaje supervisado: Clasificación parte 1
#
# 4. Clase 4:
#     10. Aprendizaje supervisado: Clasificación parte 2
#     11. Aprendizaje no supervisado: Clustering
# 5. Clase 5:
#     12. Segmentación de imágenes: SLIC
#     13. Evaluación
#     14. Cierre

# %% [markdown]
# # Primera clase
# ## Introducción a la Teledetección
#
# Lo que veremos en esta primera clase
# - [x] Espectro Electromagnético
# - [x] Algunas Misiones Satelitales libres
# - [x] Imágenes como arrays
# - [x] Lectura y visualización de imágenes satelitales

# %% [markdown]
# ### Objetivos de la notebook:
#
# - En esta notebook introducimos algunos aspectos del espectro electromegnético, así como las principales interacciónes de las señales con los objetos (y el medio). Luego introducimos algunas misiones satelitales con sus características en una presentación aparte.

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Interacciónes entre la señal, el medio y el blanco
#
# - Transmisión
# - Reflexión
# - Dispersión
# - Absorción
# - Emisión
# ---

# %% [markdown]
# ### Espectro Electromagnético
# ![image-2.png](attachment:image-2.png)
# ---
# ### Sistemas Ópticos
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Opacidad Atmosférica
# ![image.png](attachment:image.png)

# %% [markdown]
# Veamos el PDF de misiones satelitales.
